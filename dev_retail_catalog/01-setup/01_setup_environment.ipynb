# %%
# %run ../00-common/01_env_helpers

# %%
# %sql
CREATE  EXTERNAL LOCATION IF NOT EXISTS sadevelopmentretail
URL 'abfss://retail-project@sadevelopmentretail.dfs.core.windows.net/landing'
WITH (CREDENTIAL `access-connector-development-retail`)
COMMENT 'created external location to fetch the files/data'

# %%
# %sql
CREATE CATALOG IF NOT EXISTS IDENTIFIER(:Environment || '_retail_catalog');
CREATE SCHEMA IF NOT EXISTS IDENTIFIER(:Environment || '_retail_catalog' || '.landing')

# %%
display(dbutils.fs.ls(storage_path))

# %%
# %sql
USE CATALOG IDENTIFIER(:Environment || '_retail_catalog');
USE SCHEMA landing;
CREATE VOLUME IF NOT EXISTS source_files;

# %%
dbutils.fs.cp(storage_path, volume_path, recurse= True)
