# %%
dbutils.widgets.text('Environment', 'development')

# %%
catalog_name = f"{dbutils.widgets.get('Environment')}_retail_catalog"
volume_path = '/Volumes/development_retail_catalog/landing/source_files'
storage_path = 'abfss://retail-project@sadevelopmentretail.dfs.core.windows.net/landing'
