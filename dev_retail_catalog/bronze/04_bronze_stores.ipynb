# %%
# %run ./00_bronze_helpers

# %%
file_name = 'stores'
df= read_volume(file_name, file_type='csv')
spark.sql(f'CREATE SCHEMA IF NOT EXISTS {schema_name}');
df.write.mode('overwrite').saveAsTable(f'{catalog_name}.{schema_name}.{file_name}')
